# %% [markdown]
# # Combining DataFrames

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
one = pd.DataFrame({
   'name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5'],
   'marks_scored':[98,90,87,69,78]},
   index=[1,2,3,4,5])

two = pd.DataFrame({
   'name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5'],
   'marks_scored':[89,80,79,97,88]},
   index=[1,2,3,4,5])

# %%
one
# Out:
#      name subject_id  marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78

# %%
two
# Out:
#     name subject_id  marks_scored
# 1  Billy       sub2            89
# 2  Brian       sub4            80
# 3   Bran       sub3            79
# 4  Bryce       sub6            97
# 5  Betty       sub5            88

# %% [markdown]
# ## concat()

# %%
pd.concat([one, two])
# Out:
#      name subject_id  marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %%
pd.concat([one, two], ignore_index = True)
# Out:
#      name subject_id  marks_scored
# 0    Alex       sub1            98
# 1     Amy       sub2            90
# 2   Allen       sub4            87
# 3   Alice       sub6            69
# 4  Ayoung       sub5            78
# 5   Billy       sub2            89
# 6   Brian       sub4            80
# 7    Bran       sub3            79
# 8   Bryce       sub6            97
# 9   Betty       sub5            88

# %%
pd.concat([one, two], axis = 1) # not a very sensible concationation method
# Out:
#      name subject_id  marks_scored   name subject_id  marks_scored
# 1    Alex       sub1            98  Billy       sub2            89
# 2     Amy       sub2            90  Brian       sub4            80
# 3   Allen       sub4            87   Bran       sub3            79
# 4   Alice       sub6            69  Bryce       sub6            97
# 5  Ayoung       sub5            78  Betty       sub5            88

# %%
pd.concat([one, two], ignore_index = True, axis = 1)
# Out:
#         0     1   2      3     4   5
# 1    Alex  sub1  98  Billy  sub2  89
# 2     Amy  sub2  90  Brian  sub4  80
# 3   Allen  sub4  87   Bran  sub3  79
# 4   Alice  sub6  69  Bryce  sub6  97
# 5  Ayoung  sub5  78  Betty  sub5  88

# %% [markdown]
# ## merge()

# %%
x = pd.DataFrame({'product': ['pants', 'shirt', 'cap','boat'],
                     'Ankara': [3,4,6,0],
                     'Bursa': [0,5,2,8]})

y = pd.DataFrame({'product': ['pants', 'shirt', 'cap','coat'],
                          'Istanbul': [2,1,0,7],
                          'Izmir': [3,2,2,0]})

# %%
x
# Out:
#   product  Ankara  Bursa
# 0   pants       3      0
# 1   shirt       4      5
# 2     cap       6      2
# 3    boat       0      8

# %%
y
# Out:
#   product  Istanbul  Izmir
# 0   pants         2      3
# 1   shirt         1      2
# 2     cap         0      2
# 3    coat         7      0

# %%
pd.merge(x, y) # as default it makes inner join
# it gets the common data from both dataframes
# Out:
#   product  Ankara  Bursa  Istanbul  Izmir
# 0   pants       3      0         2      3
# 1   shirt       4      5         1      2
# 2     cap       6      2         0      2

# %%
pd.merge(x, y, how = 'left')
# Out:
#   product  Ankara  Bursa  Istanbul  Izmir
# 0   pants       3      0       2.0    3.0
# 1   shirt       4      5       1.0    2.0
# 2     cap       6      2       0.0    2.0
# 3    boat       0      8       NaN    NaN

# %%
pd.merge(x, y, how = 'left', on = 'product')
# when you have multiple common fileds you can use the on attribute
# Out:
#   product  Ankara  Bursa  Istanbul  Izmir
# 0   pants       3      0       2.0    3.0
# 1   shirt       4      5       1.0    2.0
# 2     cap       6      2       0.0    2.0
# 3    boat       0      8       NaN    NaN

# %%
pd.merge(x, y, how = 'right', on = 'product')
# Out:
#   product  Ankara  Bursa  Istanbul  Izmir
# 0   pants     3.0    0.0         2      3
# 1   shirt     4.0    5.0         1      2
# 2     cap     6.0    2.0         0      2
# 3    coat     NaN    NaN         7      0

# %%
pd.merge(x, y, how = 'outer', on = 'product')
# Out:
#   product  Ankara  Bursa  Istanbul  Izmir
# 0    boat     0.0    8.0       NaN    NaN
# 1     cap     6.0    2.0       0.0    2.0
# 2    coat     NaN    NaN       7.0    0.0
# 3   pants     3.0    0.0       2.0    3.0
# 4   shirt     4.0    5.0       1.0    2.0

# %%
 df1 = pd.DataFrame({'lkey': ['x', 'y', 'z', 'x'],
                    'lvalue': [2, 3, 5, 7]})

df2 = pd.DataFrame({'rkey': ['a', 'x', 'z', 'b'],
                    'rvalue': [7, 8, 9, 10]})

# %%
df1
# Out:
#   lkey  lvalue
# 0    x       2
# 1    y       3
# 2    z       5
# 3    x       7

# %%
df2
# Out:
#   rkey  rvalue
# 0    a       7
# 1    x       8
# 2    z       9
# 3    b      10

# %%
pd.merge(df1, df2, how = 'inner') # ERROR -->  No common columns to perform merge on.

# %%
pd.merge(df1, df2, how = 'inner', left_on = 'lkey', right_on = 'rkey')
# Out:
#   lkey  lvalue rkey  rvalue
# 0    x       2    x       8
# 1    z       5    z       9
# 2    x       7    x       8

# %%
pd.merge(df1, df2, how = 'left', left_on = 'lkey', right_on = 'rkey')
# Out:
#   lkey  lvalue rkey  rvalue
# 0    x       2    x     8.0
# 1    y       3  NaN     NaN
# 2    z       5    z     9.0
# 3    x       7    x     8.0

# %% [markdown]
# ## join()

# %%
df3 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index = ['K0', 'K1', 'K2']) 

df4 = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index = ['K0', 'K2', 'K3'])

# %%
df3
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
df4
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
df3.join(df4)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
df4.join(df3)
# Out:
#      C   D    A    B
# K0  C0  D0   A0   B0
# K2  C2  D2   A2   B2
# K3  C3  D3  NaN  NaN

# %%
df3.join(df4, how = 'outer') # fully joined, no data loss
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
df5 = pd.DataFrame({'key': ['K0', 'K2', 'K3', 'K4', 'K5', 'K6'],
                   'X': ['X0', 'X2', 'X3', 'X4', 'X5', 'X6']})

df6 = pd.DataFrame({'key': ['K0', 'K2', 'K3'],
                      'Y': ['Y0', 'Y2', 'Y3']})

# %%
df5
# Out:
#   key   X
# 0  K0  X0
# 1  K2  X2
# 2  K3  X3
# 3  K4  X4
# 4  K5  X5
# 5  K6  X6

# %%
df6
# Out:
#   key   Y
# 0  K0  Y0
# 1  K2  Y2
# 2  K3  Y3

# %%
df5.join(df6) # ERROR --> columns overlap

# %%
df5.join(df6, lsuffix = 'left')
# Out:
#   keyleft   X  key    Y
# 0      K0  X0   K0   Y0
# 1      K2  X2   K2   Y2
# 2      K3  X3   K3   Y3
# 3      K4  X4  NaN  NaN
# 4      K5  X5  NaN  NaN
# 5      K6  X6  NaN  NaN

# %%
df5.join(df6, lsuffix = 'left', rsuffix = 'right')
# Out:
#   keyleft   X keyright    Y
# 0      K0  X0       K0   Y0
# 1      K2  X2       K2   Y2
# 2      K3  X3       K3   Y3
# 3      K4  X4      NaN  NaN
# 4      K5  X5      NaN  NaN
# 5      K6  X6      NaN  NaN

# %% [markdown]
# # Text Data - String Methods
#
# **str.lower():** Converts a string to lowercase
#
# **str.upper():** Converts a string to uppercase
#
# **str.capitalize():** Converts the first character to uppercase
#
# **str.title():** Converts the first character of each word to uppercase
#
# **str.swapcase():** Converts uppercase letters to lowercase and lowercase letters to uppercase
#
# **str.isalpha():** Returns True or False by checking whether all characters are in the alphabet.
#
# **str.isnumeric():** Checks whether all characters contain numeric values and returns True or False
#
# **str.isalnum():** Returns True or False by checking whether all characters contain letters or numeric values
#
# **str.endswith():** Returns True or False by checking that a string ends with the specified value
#
# **str.startswith():** Returns True or False by checking that a string starts with the specified value
#
# **str.contains():** Checks whether a substring is contained in a string, returning True or False for each element
#
# **str.strip():** Removes leading and trailing spaces from a string and returns a trimmed version
#
# **str.replace():** Returns a string with a specified value replaced by another value.
#
# **str.split():** Splits a string at the specified delimiter and returns a list
#
# **str.find():** Searches for a specified value in a string and returns the index of its location
#
# **str.findall():** Returns a list of all instances in a pattern
#
# **str.join():** Converts the elements of an iterable to a string

# %%
df = pd.DataFrame(data=[['Tyler DURDEN', 'HR', "manager", "$180,000", 55],
                        ['MARIA puder', "IT", "data analyst", "150000dolar", 28],
                        ['dorothy gale', "HR", "recruiter", "$120,000", 30],
                        ['Edmond Dantes', "IT", "data scientist", "$170,000","-"], 
                        ['Gregor SAMSA',"IT", "frontend developer", "120000dolar",32]],
                  columns=["name","dept", "job", "salary", "age"])
df
# Out:
#             name dept                 job       salary age
# 0   Tyler DURDEN   HR             manager     $180,000  55
# 1    MARIA puder   IT        data analyst  150000dolar  28
# 2   dorothy gale   HR           recruiter     $120,000  30
# 3  Edmond Dantes   IT      data scientist     $170,000   -
# 4   Gregor SAMSA   IT  frontend developer  120000dolar  32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   dept    5 non-null      object
#  2   job     5 non-null      object
#  3   salary  5 non-null      object
#  4   age     5 non-null      object
# dtypes: object(5)
# memory usage: 332.0+ bytes

# %%
df.name.str.title()
# Out:
# 0     Tyler Durden
# 1      Maria Puder
# 2     Dorothy Gale
# 3    Edmond Dantes
# 4     Gregor Samsa
# Name: name, dtype: object

# %%
'welcome melisa'.title()
# Out:
# 'Welcome Melisa'

# %%
df.name
# Out:
# 0     Tyler DURDEN
# 1      MARIA puder
# 2     dorothy gale
# 3    Edmond Dantes
# 4     Gregor SAMSA
# Name: name, dtype: object

# %%
df.name =df.name.str.title() # because inplace = True doesnt work, 
# we make an assignment to make the change permanent

# %%
df.name
# Out:
# 0     Tyler Durden
# 1      Maria Puder
# 2     Dorothy Gale
# 3    Edmond Dantes
# 4     Gregor Samsa
# Name: name, dtype: object

# %%
df.age.str.isnumeric()
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3    False
# 4      NaN
# Name: age, dtype: object

# %%
df.age.astype('str').str.isnumeric()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: age, dtype: bool

# %%
df.age.astype('str').str.isnumeric().sum()
# Out:
# np.int64(4)

# %%
df['age'].replace('-', np.nan, inplace = True)

# %%
df
# Out:
#             name dept                 job       salary   age
# 0   Tyler Durden   HR             manager     $180,000  55.0
# 1    Maria Puder   IT        data analyst  150000dolar  28.0
# 2   Dorothy Gale   HR           recruiter     $120,000  30.0
# 3  Edmond Dantes   IT      data scientist     $170,000   NaN
# 4   Gregor Samsa   IT  frontend developer  120000dolar  32.0

# %%
df.salary.str.startswith('$').sum()
# Out:
# np.int64(3)

# %%
# contains
df.job == 'data analyst'
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: job, dtype: bool

# %%
df[df.job == 'data analyst']
# Out:
#           name dept           job       salary   age
# 1  Maria Puder   IT  data analyst  150000dolar  28.0

# %%
df[df.job.str.contains('data')]
# Out:
#             name dept             job       salary   age
# 1    Maria Puder   IT    data analyst  150000dolar  28.0
# 3  Edmond Dantes   IT  data scientist     $170,000   NaN

# %%
df
# Out:
#             name dept                 job       salary   age
# 0   Tyler Durden   HR             manager     $180,000  55.0
# 1    Maria Puder   IT        data analyst  150000dolar  28.0
# 2   Dorothy Gale   HR           recruiter     $120,000  30.0
# 3  Edmond Dantes   IT      data scientist     $170,000   NaN
# 4   Gregor Samsa   IT  frontend developer  120000dolar  32.0

# %%
df.salary.str.strip('$dolar')
# Out:
# 0    180,000
# 1     150000
# 2    120,000
# 3    170,000
# 4     120000
# Name: salary, dtype: object

# %%
df.salary.str.strip('dolar')
# strip function only looks at the beginning and the end
# Out:
# 0    $180,000
# 1      150000
# 2    $120,000
# 3    $170,000
# 4      120000
# Name: salary, dtype: object

# %%
df.salary.str.strip('$dolar').str.replace(',', '')
# Out:
# 0    180000
# 1    150000
# 2    120000
# 3    170000
# 4    120000
# Name: salary, dtype: object

# %%
df.salary.str.strip('$dolar').str.replace(',', '').astype(int)
# Out:
# 0    180000
# 1    150000
# 2    120000
# 3    170000
# 4    120000
# Name: salary, dtype: int64

# %%
df.salary = df.salary.str.strip('$dolar').str.replace(',', '').astype(int)
df.salary
# by assigning we made the change permanent
# Out:
# 0    180000
# 1    150000
# 2    120000
# 3    170000
# 4    120000
# Name: salary, dtype: int64

# %%
df
# Out:
#             name dept                 job  salary   age
# 0   Tyler Durden   HR             manager  180000  55.0
# 1    Maria Puder   IT        data analyst  150000  28.0
# 2   Dorothy Gale   HR           recruiter  120000  30.0
# 3  Edmond Dantes   IT      data scientist  170000   NaN
# 4   Gregor Samsa   IT  frontend developer  120000  32.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   dept    5 non-null      object
#  2   job     5 non-null      object
#  3   salary  5 non-null      int64
#  4   age     4 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 332.0+ bytes

# %% [markdown]
# # Dummy Operations
#
# **get_dummies()** is a function commonly used in machine learning and data analysis.

# %%
df
# Out:
#             name dept                 job  salary   age
# 0   Tyler Durden   HR             manager  180000  55.0
# 1    Maria Puder   IT        data analyst  150000  28.0
# 2   Dorothy Gale   HR           recruiter  120000  30.0
# 3  Edmond Dantes   IT      data scientist  170000   NaN
# 4   Gregor Samsa   IT  frontend developer  120000  32.0

# %%
pd.get_dummies(df.dept)
# Out:
#       HR     IT
# 0   True  False
# 1  False   True
# 2   True  False
# 3  False   True
# 4  False   True

# %%
pd.get_dummies(df.dept, drop_first = True)
# Out:
#       IT
# 0  False
# 1   True
# 2  False
# 3   True
# 4   True

# %%
pd.get_dummies(df.job)
# Out:
#    data analyst  data scientist  frontend developer  manager  recruiter
# 0         False           False               False     True      False
# 1          True           False               False    False      False
# 2         False           False               False    False       True
# 3         False            True               False    False      False
# 4         False           False                True    False      False

# %%
pd.get_dummies(df.job, drop_first = True)
# Out:
#    data scientist  frontend developer  manager  recruiter
# 0           False               False     True      False
# 1           False               False    False      False
# 2           False               False    False       True
# 3            True               False    False      False
# 4           False                True    False      False

# %%
pd.get_dummies(df) # this is not sensible
# Out:
#    salary   age  name_Dorothy Gale  name_Edmond Dantes  name_Gregor Samsa  \
# 0  180000  55.0              False               False              False
# 1  150000  28.0              False               False              False
# 2  120000  30.0               True               False              False
# 3  170000   NaN              False                True              False
# 4  120000  32.0              False               False               True
#
#    name_Maria Puder  name_Tyler Durden  dept_HR  dept_IT  job_data analyst  \
# 0             False               True     True    False             False
# 1              True              False    False     True              True
# 2             False              False     True    False             False
# 3             False              False    False     True             False
# 4             False              False    False     True             False
#
#    job_data scientist  job_frontend developer  job_manager  job_recruiter
# 0               False                   False         True          False
# 1               False                   False        False          False
# 2               False                   False        False           True
# 3                True                   False        False          False
# 4               False                    True        False          False

# %%
pd.get_dummies(df, columns = ['dept', 'job']) # specified two columns
# Out:
#             name  salary   age  dept_HR  dept_IT  job_data analyst  \
# 0   Tyler Durden  180000  55.0     True    False             False
# 1    Maria Puder  150000  28.0    False     True              True
# 2   Dorothy Gale  120000  30.0     True    False             False
# 3  Edmond Dantes  170000   NaN    False     True             False
# 4   Gregor Samsa  120000  32.0    False     True             False
#
#    job_data scientist  job_frontend developer  job_manager  job_recruiter
# 0               False                   False         True          False
# 1               False                   False        False          False
# 2               False                   False        False           True
# 3                True                   False        False          False
# 4               False                    True        False          False

# %%
df_result = pd.get_dummies(df, columns = ['dept', 'job']) 
df_result
# Out:
#             name  salary   age  dept_HR  dept_IT  job_data analyst  \
# 0   Tyler Durden  180000  55.0     True    False             False
# 1    Maria Puder  150000  28.0    False     True              True
# 2   Dorothy Gale  120000  30.0     True    False             False
# 3  Edmond Dantes  170000   NaN    False     True             False
# 4   Gregor Samsa  120000  32.0    False     True             False
#
#    job_data scientist  job_frontend developer  job_manager  job_recruiter
# 0               False                   False         True          False
# 1               False                   False        False          False
# 2               False                   False        False           True
# 3                True                   False        False          False
# 4               False                    True        False          False

# %%
df_result.to_csv('df_result.csv')

# %%
pd.read_csv('df_result.csv')
# Out:
#    Unnamed: 0           name  salary   age  dept_HR  dept_IT  \
# 0           0   Tyler Durden  180000  55.0     True    False
# 1           1    Maria Puder  150000  28.0    False     True
# 2           2   Dorothy Gale  120000  30.0     True    False
# 3           3  Edmond Dantes  170000   NaN    False     True
# 4           4   Gregor Samsa  120000  32.0    False     True
#
#    job_data analyst  job_data scientist  job_frontend developer  job_manager  \
# 0             False               False                   False         True
# 1              True               False                   False        False
# 2             False               False                   False        False
# 3             False                True                   False        False
# 4             False               False                    True        False
#
#    job_recruiter
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False

# %%
pd.read_csv('df_result.csv', index_col = 0)
# Out:
#             name  salary   age  dept_HR  dept_IT  job_data analyst  \
# 0   Tyler Durden  180000  55.0     True    False             False
# 1    Maria Puder  150000  28.0    False     True              True
# 2   Dorothy Gale  120000  30.0     True    False             False
# 3  Edmond Dantes  170000   NaN    False     True             False
# 4   Gregor Samsa  120000  32.0    False     True             False
#
#    job_data scientist  job_frontend developer  job_manager  job_recruiter
# 0               False                   False         True          False
# 1               False                   False        False          False
# 2               False                   False        False           True
# 3                True                   False        False          False
# 4               False                    True        False          False

# %%
df_result.to_csv('df_result1.csv', index = False)
# if you dont change the name you made before it overwrites it.
# by using index = False we didnt get the previous indexes

# %%
pd.read_csv('df_result1.csv')
# Out:
#             name  salary   age  dept_HR  dept_IT  job_data analyst  \
# 0   Tyler Durden  180000  55.0     True    False             False
# 1    Maria Puder  150000  28.0    False     True              True
# 2   Dorothy Gale  120000  30.0     True    False             False
# 3  Edmond Dantes  170000   NaN    False     True             False
# 4   Gregor Samsa  120000  32.0    False     True             False
#
#    job_data scientist  job_frontend developer  job_manager  job_recruiter
# 0               False                   False         True          False
# 1               False                   False        False          False
# 2               False                   False        False           True
# 3                True                   False        False          False
# 4               False                    True        False          False

# %%
df_result.to_excel('df_result.xlsx', index = False)

# %%
pd.read_excel('df_result.xlsx')
# Out:
#             name  salary   age  dept_HR  dept_IT  job_data analyst  \
# 0   Tyler Durden  180000  55.0     True    False             False
# 1    Maria Puder  150000  28.0    False     True              True
# 2   Dorothy Gale  120000  30.0     True    False             False
# 3  Edmond Dantes  170000   NaN    False     True             False
# 4   Gregor Samsa  120000  32.0    False     True             False
#
#    job_data scientist  job_frontend developer  job_manager  job_recruiter
# 0               False                   False         True          False
# 1               False                   False        False          False
# 2               False                   False        False           True
# 3                True                   False        False          False
# 4               False                    True        False          False

# %%
df_html = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 df_html = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population')
#
# File c:\Users\mehme\anaconda3\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
#    1243     match=match,
#    1244     header=header,
#    1245     index_col=index_col,
#    1246     skiprows=skiprows,
#    1247     parse_dates=parse_dates,
#    1248     thousands=thousands,
#    1249     attrs=attrs,
#    1250     encoding=encoding,
#    1251     decimal=decimal,
#    1252     converters=converters,
#    1253     na_values=na_values,
#    1254     keep_default_na=keep_default_na,
#    1255     displayed_only=displayed_only,
#    1256     extract_links=extract_links,
#    1257     dtype_backend=dtype_backend,
#    1258     storage_options=storage_options,
#    1259 )
#
# File c:\Users\mehme\anaconda3\Lib\site-packages\pandas\io\html.py:983, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     972 p = parser(
#     973     io,
#     974     compiled_match,
#    (...)
#     979     storage_options,
#     980 )
#     982 try:
# --> 983     tables = p.parse_tables()
#     984 except ValueError as caught:
#     985     # if `io` is an io-like object, check if it's seekable
#     986     # and try to rewind it before trying the next parser
#     987     if hasattr(io, "seekable") and io.seekable():
#
# File c:\Users\mehme\anaconda3\Lib\site-packages\pandas\io\html.py:249, in _HtmlFrameParser.parse_tables(self)
#     241 def parse_tables(self):
#     242     """
#     243     Parse and return all tables from the DOM.
#     244
#    (...)
#     247     list of parsed (header, body, footer) tuples from tables.
#     248     """
# --> 249     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     250     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File c:\Users\mehme\anaconda3\Lib\site-packages\pandas\io\html.py:806, in _LxmlFrameParser._build_doc(self)
#     804             pass
#     805     else:
# --> 806         raise e
#     807 else:
#     808     if not hasattr(r, "text_content"):
#
# File c:\Users\mehme\anaconda3\Lib\site-packages\pandas\io\html.py:785, in _LxmlFrameParser._build_doc(self)
#     783 try:
#     784     if is_url(self.io):
# --> 785         with get_handle(
#     786             self.io, "r", storage_options=self.storage_options
#     787         ) as f:
#     788             r = parse(f.handle, parser=parser)
#     789     else:
#     790         # try to parse the input in the simplest way
#
# File c:\Users\mehme\anaconda3\Lib\site-packages\pandas\io\common.py:728, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     725     codecs.lookup_error(errors)
#     727 # open URLs
# --> 728 ioargs = _get_filepath_or_buffer(
#     729     path_or_buf,
#     730     encoding=encoding,
#     731     compression=compression,
#     732     mode=mode,
#     733     storage_options=storage_options,
#     734 )
#     736 handle = ioargs.filepath_or_buffer
#     737 handles: list[BaseBuffer]
#
# File c:\Users\mehme\anaconda3\Lib\site-packages\pandas\io\common.py:384, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382 # assuming storage_options is to be interpreted as headers
#     383 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384 with urlopen(req_info) as req:
#     385     content_encoding = req.headers.get("Content-Encoding", None)
#     386     if content_encoding == "gzip":
#     387         # Override compression based on Content-Encoding header
#
# File c:\Users\mehme\anaconda3\Lib\site-packages\pandas\io\common.py:289, in urlopen(*args, **kwargs)
#     283 """
#     284 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     285 the stdlib.
#     286 """
#     287 import urllib.request
# --> 289 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\mehme\anaconda3\Lib\urllib\request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File c:\Users\mehme\anaconda3\Lib\urllib\request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     493 for processor in self.process_response.get(protocol, []):
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# File c:\Users\mehme\anaconda3\Lib\urllib\request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#     601 # According to RFC 2616, "2xx" code indicates that the client's
#     602 # request was successfully received, understood, and accepted.
#     603 if not (200 <= code < 300):
# --> 604     response = self.parent.error(
#     605         'http', request, response, code, msg, hdrs)
#     607 return response
#
# File c:\Users\mehme\anaconda3\Lib\urllib\request.py:533, in OpenerDirector.error(self, proto, *args)
#     531 if http_err:
#     532     args = (dict, 'default', 'http_error_default') + orig_args
# --> 533     return self._call_chain(*args)
#
# File c:\Users\mehme\anaconda3\Lib\urllib\request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File c:\Users\mehme\anaconda3\Lib\urllib\request.py:613, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     612 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
df_html
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[215], line 1
# ----> 1 df_html
#
# NameError: name 'df_html' is not defined
